# %%
from langchain_core.messages import HumanMessage
from agents import EDAgent
import pandas as pd
from langchain_openai import ChatOpenAI

df = pd.read_csv("./titanic.csv")
llm = ChatOpenAI(model="gpt-4o", api_key="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")
agent = EDAgent(llm)

from IPython.display import Image, display, Markdown

display(Image(agent.graph.get_graph().draw_mermaid_png()))

# %%
print(df.dtypes)
print('o')
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# o
